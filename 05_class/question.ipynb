# %% [markdown]
# ### **문제 1: 클래스 속성, 인스턴스 속성 테스트**
#
# 카피바라는 이직 준비를 위해 자기소개서를 작성해야 합니다. `Squirrel`이라는 클래스를 만들어 카피바라의 기본 정보를 설정하세요.
#
# 1. 클래스 속성 `species`를 설정하여 "카피바라"로 초기화하세요.
# 2. 생성자를 통해 인스턴스 속성 `name`과 `current_job`을 설정하세요.
# 3. 메서드 `introduce`를 만들어 이름과 현재 직업을 소개하는 문자열을 반환하세요.
# 4. 다른 인스턴스를 생성해도 `species`는 공유되지만, `name`과 `current_job`은 서로 독립적임을 확인하세요.

# %%
class Capybara:
    species = '카피바라'

    def __init__(self, name, current_job): # 이 객체가 가지고 있는 특성을 먼저 정의. / self - 기본적으로 자기 자신에 접근. => 즉 생성자는 나만의 속성을 정의하는 데에 사용됨!
        self.name = name
        self.current_job = current_job

    def introduce(self): # self- 자기 자신의 정보값을 불러오는 역할.
        # print(f'이름은 {self.name}이고, 현재 직업은 {self.current_job}입니다.')
        return '제 이름은 ' + self.name + '이고, 현재 직업은 ' + self.current_job + '입니다.'   

c1 = Capybara('바라', '바리스타')   # 객체 생성.
c2 = Capybara('판다', '사육사')   # 객체 생성.

print(c1.species)

print(c1.introduce())
print(c2.introduce())
# Out:
# 카피바라
# 제 이름은 바라이고, 현재 직업은 바리스타입니다.
# 제 이름은 판다이고, 현재 직업은 사육사입니다.

# %% [markdown]
# ### **문제 2: 클래스 속성과 인스턴스 속성의 차이**
#
# 카피바라는 이직 준비를 하며 다양한 직업 스킬을 학습 중입니다. 클래스 속성과 인스턴스 속성의 차이를 확인하세요.
#
# 1. `Character` 클래스를 생성하세요.
# 2. 클래스 속성 `skills`를 정의하여 빈 리스트로 초기화하세요.
# 3. 생성자에서 인스턴스 속성 `skills`를 별도로 초기화하세요.
# 4. `add_skill` 메서드에서 클래스 속성이 아닌 인스턴스 속성에 스킬을 추가하도록 수정하세요.

# %%
class Character:
    skills = []

    def __init__(self):
        self.skills = []

    def add_skill(self, skill):
        self.skills.append(skill)

my_character1 = Character()
my_character2 = Character()

my_character1.add_skill('금강불괴')
my_character2.add_skill('날라차기')

print(my_character1.skills)
print(my_character2.skills)
# Out:
# ['금강불괴']
# ['날라차기']

# %%
class Character:
    skills = []

    def __init__(self, skills):
        self.skills = skills

    def add_skill(self, skill):
        self.skills.append(skill)

# %% [markdown]
# ### **문제 3: 인스턴스 속성과 클래스 속성의 우선순위**
#
# 카피바라는 이직을 위해 별명을 여러 개 사용합니다. 클래스 속성으로 `nickname`을 설정하지만, 각 인스턴스마다 별명을 변경할 수 있습니다.
#
# 1. `Character` 클래스에 클래스 속성 `nickname`을 설정하세요.
# 2. 생성자에서 인스턴스 속성 `nickname`을 설정하세요.
# 3. 클래스 속성과 인스턴스 속성이 충돌할 때, 인스턴스 속성이 우선됨을 확인하세요.
#
#     ---

# %%
class Character:
    nickname = '클래스 nickname'

    def __init__(self, nickname):
        self.nickname = nickname

ch1 = Character('별명1')
ch2 = Character('별명22')

print(ch1.nickname)
print(ch2.nickname)
# Out:
# 별명1
# 별명22

# %%
class Character:
    nickname = ''

    def __init__(self, nickname):
        self.nickname = nickname

    print(nickname)

# %% [markdown]
# ### **문제 4: 네임스페이스 테스트 - 전역과 로컬**
#
# 카피바라는 이직 준비 도구를 사용하며, 전역 변수와 로컬 변수를 관리합니다. `namespace_test` 함수를 작성해 네임스페이스를 테스트하세요.
#
# 1. 전역 변수 `tool`을 "연필"로 설정하세요.
# 2.  함수 `namespace_test` 내부에 로컬 변수 `local_tool`을 "키보드"로 설정하고, `global` 키워드를 사용해 전역 변수를 "펜"으로 수정하세요.
# 3. 함수 내부에서 로컬 변수와 전역 변수의 값을 출력하세요.

# %%
tool = '연필'

def namespace_test():
    local_tool = '키보드'
    global tool
    tool = '펜'

    print(local_tool)
    print(tool)

namespace_test() # 를 실행하면, 바로 위의 print(local_tool) print(tool) 요 구문이 실행됨
# print(tool)
# Out:
# 키보드
# 펜

# %%
tool = '연필'

def namespace_test():
    local_tool = '키보드'
    global tool
    tool = '펜'

    print(local_tool)
    print(tool)

# %% [markdown]
# ### **문제 5: 네임스페이스 테스트 - 클래스와 인스턴스**
#
# 카피바라는 이직 준비 중 클래스를 통해 도구를 관리합니다. `Toolbox` 클래스를 만들어 네임스페이스를 테스트하세요.
#
# 1. 클래스 속성 `tools`를 ["노트북", "책상"]으로 초기화하세요.
# 2. 생성자를 통해 인스턴스 속성 `tools`를 설정하고, 객체마다 다른 도구를 가질 수 있도록 설정하세요.
# 3. `add_tool` 메서드를 만들어 인스턴스 속성에 새 도구를 추가하세요.

# %%
class Toolbox:
    tools = ['노트북', '책상']
    
    def __init__(self):
        self.tools = []

    def add_tool(self, tool):
        self.tools.append(tool)

my_tool1 = Toolbox()
my_tool2 = Toolbox()

my_tool1.add_tool('컴퓨터')
my_tool1.add_tool('의자')
my_tool2.add_tool('마우스')
my_tool2.add_tool('모니터')

print(my_tool1.tools)
print(my_tool2.tools)

print(Toolbox.tools)
# Out:
# ['컴퓨터', '의자']
# ['마우스', '모니터']
# ['노트북', '책상']

# %%
class Toolbox:
    tools = ['노트북', '책상']
    
    # def __init__(self, tool):
    #     self.tool = tool

    def add_tool(self, tool):
        self.tools.append(tool)

# my_tool = Toolbox('')
my_tool = Toolbox()
my_tool.add_tool('컴퓨터')
my_tool.add_tool('의자')
my_tool.add_tool('마우스')
my_tool.add_tool('모니터')
print(my_tool.tools)
# Out:
# ['노트북', '책상', '컴퓨터', '의자', '마우스', '모니터']

# %% [markdown]
# ### **문제 6: 네임스페이스 테스트 - nonlocal**
#
# 카피바라는 이직 준비 중 추가적인 정보가 필요합니다. 중첩 함수와 `nonlocal` 키워드를 사용해 바깥 함수의 변수를 수정하세요.
#
# 1. 함수 `nested_function`을 작성하세요.
#
# 1. 바깥 함수의 변수 `status`를 "작성 중"으로 초기화하세요.
# 2. 중첩 함수에서 `status`를 "완료"로 수정하세요.

# %%
def nested_funtion():
    status = '작성 중'

    def inner_funtion():
        nonlocal status
        status = '완료'

    inner_funtion()
    
    print(status)

nested_funtion()
# Out:
# 완료

# %%
def nested_funtion():
    status = '작성 중'

    def fun():
        nonlocal status
        status = '완료'

    print(status) # 아직 fun 안 호출해서 상태가 완료로 바뀌지 않고, 초기상태.
    fun()
    print(status)
nested_funtion()
# Out:
# 작성 중
# 완료

# %% [markdown]
# ### 문제 1: **기본 상속을 활용한 클래스 생성**
#
# ---
#
# 카피바라는 이직을 준비하며 새로운 직업군을 탐색하고 있습니다. 카피바라의 기본적인 정보를 담는 `Person` 클래스를 만들고, 이를 상속받는 `Candidate` 클래스를 생성하세요.
#
# 1. `Person` 클래스:
#     - 클래스 속성 `national`은 "Korea"로 설정합니다.
#     - 메서드 `introduce`는 `"안녕하세요, 저는 한국에서 왔습니다."`를 반환합니다.
# 2. `Candidate` 클래스:
#     - `Person` 클래스를 상속받습니다.
#     - 생성자에서 이름(`name`)과 관심 분야(`field`)를 매개변수로 받아 저장합니다.
#     - 메서드 `introduce`를 오버라이드하여 `"안녕하세요, 저는 [name]입니다. [field] 분야에 관심이 있습니다."`를 반환합니다.

# %%
class Person:
    national = 'Korea'

    def introduce(self):
        return '안녕하세요, 저는 한국에서 왔습니다.'
    
class Candidate(Person):
    def __init__(self, name, field):
        self.name = name
        self.field = field

    def introduce(self):
        return f'안녕하세요, 저는 {self.name}입니다. {self.field} 분야에 관심이 있습니다.'
    
a = Candidate('김이름', '놀기')
print(a.introduce())

pers = Person()
cand = Candidate('바라', 'python')
print(p.national)
# Out:
# 안녕하세요, 저는 김이름입니다. 놀기 분야에 관심이 있습니다.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 20
#      16 print(a.introduce())
#      17
#      18 pers = Person()
#      19 cand = Candidate('바라', 'python')
# ---> 20 print(p.national)
#
# NameError: name 'p' is not defined

# %% [markdown]
# ### 문제 2: **다중 상속을 활용한 클래스 생성**
#
# 카피바라는 이직을 준비하며 여러 강사님들의 도움을 받고 있습니다. 강사의 역할을 분리한 클래스를 만들어 상속 구조를 테스트하세요.
#
# 1. `Mentor` 클래스:
#     - 메서드 `guide`는 `"이직 준비를 도와드립니다."`를 반환합니다.
# 2. `Lecturer` 클래스:
#     - 메서드 `teach`는 `"이직에 필요한 기술을 가르쳐드립니다."`를 반환합니다.
# 3. `Coach` 클래스:
#     - `Mentor`와 `Lecturer` 클래스를 다중 상속받습니다.
#     - 메서드 `support`는 `"여러 방면으로 지원을 아끼지 않겠습니다."`를 반환합니다.

# %%
class Mentor:
    def guide(self):
        return '이직 준비를 도와드립니다.'
    
class Lecturer:
    def teach(self):
        return '이직에 필요한 기술을 가르쳐드립니다.'
    
class Coach(Mentor, Lecturer):
    def support(self):
        return '여러 방면으로 지원을 아끼지 않겠습니다.'
    
m = Mentor()
l = Lecturer()
c = Coach()

print(m.guide())
print(l.teach())
print(c.guide()) #오버라이딩
print(c.teach()) #오버라이딩
print(c.support())
# Out:
# 이직 준비를 도와드립니다.
# 이직에 필요한 기술을 가르쳐드립니다.
# 이직 준비를 도와드립니다.
# 이직에 필요한 기술을 가르쳐드립니다.
# 여러 방면으로 지원을 아끼지 않겠습니다.

# %% [markdown]
# ### 문제 3: **부모 클래스 속성 오버라이딩**
#
# 카피바라는 이직 준비를 위해 개인적인 특성을 강조하고 있습니다. 부모 클래스의 메서드를 오버라이딩하여 각기 다른 인스턴스를 만들어보세요.
#
# 1. `Person` 클래스:
#     - 속성 `name`과 `national`을 생성자로 받아 저장합니다.
#     - 메서드 `introduce`는 `"안녕하세요, 저는 [name]입니다. 저는 [national]에서 왔습니다."`를 반환합니다.
# 2. `Candidate` 클래스:
#     - `Person` 클래스를 상속받습니다.
#     - `introduce` 메서드를 오버라이드하여 `"안녕하세요, 제 이름은 [name]이고, 이직 준비 중입니다."`를 반환합니다.

# %%
class Person:
    def __init__(self, name, national):
        self.name = name
        self.national = national

    def introduce(self):
        return f'안녕하세요, 저는 {self.name}입니다. 저는 {self.national}에서 왔습니다.'
    
class Candidate(Person):
    def __init__(self, name, national):
        super().__init__(name, national)
    
    def introduce(self):
        return f'안녕하세요, 제 이름은 {self.name}이고, 이직 준비 중입니다.'
    
p = Person('사람', '미국')
c = Candidate('이직맨', '한국')

print(p.introduce())
print(c.introduce())
# Out:
# 안녕하세요, 저는 사람입니다. 저는 미국에서 왔습니다.
# 안녕하세요, 제 이름은 이직맨이고, 이직 준비 중입니다.

# %% [markdown]
# ### 문제 4: **상속의 특성 통합 테스트**
#
# 카피바라는 강사님들의 지도를 받으며 다양한 분야에서 경험을 쌓고 있습니다. 상속과 메서드 오버라이딩, 다중 상속을 종합적으로 테스트하세요.
#
# 1. `Mentor` 클래스:
#     - 속성 `field`를 생성자로 받아 저장합니다.
#     - 메서드 `guide`는 `"저는 [field] 분야의 멘토입니다."`를 반환합니다.
# 2. `Lecturer` 클래스:
#     - 속성 `experience`를 생성자로 받아 저장합니다.
#     - 메서드 `teach`는 `"저는 [experience]년의 강의 경력을 가지고 있습니다."`를 반환합니다.
# 3. `Candidate` 클래스:
#     - `Mentor`와 `Lecturer` 클래스를 다중 상속받습니다.
#     - `guide` 메서드를 오버라이드하여 `"저는 [field] 분야의 강사이며, 이직 준비를 도와드립니다."`를 반환합니다.

# %%
class Mentor:
    def __init__(self, field):
        self.field = field

    def guide(self):
        return f'저는 {self.field} 분야의 멘토입니다.'
    
class Lecturer:
    def __init__(self, experience):
        self.experience = experience

    def teach(self):
        return f'저는 srt({self.experience})년의 강의 경력을 가지고 있습니다'
    
class Candidate(Mentor, Lecturer):
    def __init__(self, field, experience):
        # super().__init__(field)
        # super().__init__(experience)

        Mentor().__init__(self, field)
        Lecturer().__init__(self, experience)

    def guide(self):
        return f'저는 {self.field} 분야의 강사이며, 이직 준비를 도와드립니다'
    
m = Mentor('파이썬')
l = Lecturer(20)
c = Candidate('파이썬', 10)

print(m.guide())
print(l.teach())
print(c.guide())
print(c.teach())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 28
#      24         return f'저는 {self.field} 분야의 강사이며, 이직 준비를 도와드립니다'
#      25
#      26 m = Mentor('파이썬')
#      27 l = Lecturer(20)
# ---> 28 c = Candidate('파이썬', '10')
#      29
#      30 print(m.guide())
#      31 print(l.teach())
#
# Cell In[17], line 20, in Candidate.__init__(self, field, experience)
#      16     def __init__(self, field, experience):
#      17         # super().__init__(field)
#      18         # super().__init__(experience)
#      19
# ---> 20         Mentor().__init__(self, field)
#      21         Lecturer().__init__(self, experience)
#
# TypeError: Mentor.__init__() missing 1 required positional argument: 'field'
